# %%
##test loader
from langchain_community.document_loaders import TextLoader

loader = TextLoader('speach.txt')
text =loader.load()
text
# Out:
# [Document(metadata={'source': 'speach.txt'}, page_content="Earth is a planet in our solar system that's home to life. It's the third planet from the sun and the fifth largest planet in our solar system. \nPhysical characteristics\nShape: Earth is a sphere with a diameter of 7,917.5 miles \nComposition: Earth is made of rock, metals, and silicate rocks \nAtmosphere: Earth's atmosphere is made of 78% nitrogen, 21% oxygen, and 1% other gases \nMagnetic field: Earth's magnetic field is generated by convection currents in the outer core \nMotion \nRotation: Earth rotates on its axis every 23.9 hours, which defines day and night\nOrbit: Earth orbits the sun every 365.25 days, which defines the year\nOther facts\nEarth is known as the blue planet because of its large amount of water \nEarth's highest mountain is Mount Everest, which is part of the Himalayan mountain range \nEarth's surface is constantly changing due to convection cells inside the planet \nEarth's atmosphere protects us from
# ...

# %%
text =loader.load()
text
# Out:
# [Document(metadata={'source': 'speach.txt'}, page_content="Earth is a planet in our solar system that's home to life. It's the third planet from the sun and the fifth largest planet in our solar system. \nPhysical characteristics\nShape: Earth is a sphere with a diameter of 7,917.5 miles \nComposition: Earth is made of rock, metals, and silicate rocks \nAtmosphere: Earth's atmosphere is made of 78% nitrogen, 21% oxygen, and 1% other gases \nMagnetic field: Earth's magnetic field is generated by convection currents in the outer core \nMotion \nRotation: Earth rotates on its axis every 23.9 hours, which defines day and night\nOrbit: Earth orbits the sun every 365.25 days, which defines the year\nOther facts\nEarth is known as the blue planet because of its large amount of water \nEarth's highest mountain is Mount Everest, which is part of the Himalayan mountain range \nEarth's surface is constantly changing due to convection cells inside the planet \nEarth's atmosphere protects us from
# ...

# %%
##reading a PDF file
from langchain_community.document_loaders import PyPDFLoader
loader_pdf=PyPDFLoader("Nithin Kumar KR.pdf")
load_pdf=loader_pdf.load()
load_pdf
# Out:
# [Document(metadata={'producer': 'Qt 4.8.7', 'creator': 'wkhtmltopdf 0.12.4', 'creationdate': '2025-02-07T03:20:57+01:00', 'title': '', 'source': 'Nithin Kumar KR.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='NITHIN KUMAR K R \nData Analyst \nData Analyst with 3+ years of experience interpreting and analyzing data in\norder to drive successful business solutions. Proﬁcient knowledge in Python\n, Mysql , Metabase, Data Science, Data Engineering, AWS, Analytics, ETL,\nAirbyte , Splunk , Pyspark \nnithinkumarkr37@gmail.com \n8317487852 \nlinkedin.com/in/nithin-kumar-k-r-69a0b0192 \nWORK EXPERIENCE \nData Analyst \nStraive - Visa \n08/2024 - Present\n, \n \nBengaluru \nLed a data Analyst team proﬁcient in Python and SQL, conducting extensive data\nmining and analysis on large datasets, yielding actionable insights and driving\ninformed decision-making through advanced analytics techniques. \nPerformed statistical analysis using Python libraries such as NumPy, Pandas
# ...

# %%
load_pdf=loader_pdf.load()
load_pdf
# Out:
# [Document(metadata={'producer': 'Qt 4.8.7', 'creator': 'wkhtmltopdf 0.12.4', 'creationdate': '2025-02-07T03:20:57+01:00', 'title': '', 'source': 'Nithin Kumar KR.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='NITHIN KUMAR K R \nData Analyst \nData Analyst with 3+ years of experience interpreting and analyzing data in\norder to drive successful business solutions. Proﬁcient knowledge in Python\n, Mysql , Metabase, Data Science, Data Engineering, AWS, Analytics, ETL,\nAirbyte , Splunk , Pyspark \nnithinkumarkr37@gmail.com \n8317487852 \nlinkedin.com/in/nithin-kumar-k-r-69a0b0192 \nWORK EXPERIENCE \nData Analyst \nStraive - Visa \n08/2024 - Present\n, \n \nBengaluru \nLed a data Analyst team proﬁcient in Python and SQL, conducting extensive data\nmining and analysis on large datasets, yielding actionable insights and driving\ninformed decision-making through advanced analytics techniques. \nPerformed statistical analysis using Python libraries such as NumPy, Pandas
# ...

# %%
##Web page Loader
from langchain_community.document_loaders import WebBaseLoader
import bs4
Web_load=WebBaseLoader(web_paths=("https://musstafa0804.medium.com/road-map-to-start-data-science-journey-in-2024-a92ed8c1edad",),
                       bs_kwargs=dict(parse_only=bs4.SoupStrainer
                                      (
                                          class_=("gn go gp gq gr")
                                      ))
                                      )
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
Web_load.load()
# Out:
# [Document(metadata={'source': 'https://musstafa0804.medium.com/road-map-to-start-data-science-journey-in-2024-a92ed8c1edad'}, page_content='Road Map to start Data Science journey in 2024!Musstafa·Follow7 min read·Jan 9, 2024--ListenShareThis roadmap encompasses crucial resources necessary to embark on the journey of becoming a Data Scientist.Step 1: Getting started with Python/R.To start your data science journey, you must learn Python or R programming language. I’ll give you a walkthrough to start Python programming.Data Types in PythonOperators and Methods in PythonDecision-Making and Loops in PythonStrings, Lists, Dictionaries, Sets, and TuplesFunctions, File Handling, Exception HandlingOops, Concept.These are the main concepts that you must have to learn in Python.Now I’ll share some resources to practice these concepts:Pythonprogramming is the best free resource to get your basics clear.PrepInsta 100 codes are the best free resource to practice Python and get familiar with Pytho
# ...

# %%
from langchain_community.document_loaders import ArxivLoader
import pymupdf

# %%
docs=ArxivLoader(query="1605.08386",load_max_docs=2).load()
len(docs)
# Out:
# 1

# %%
## Text Splitting From Documents
##reading a PDF file
from langchain_community.document_loaders import PyPDFLoader
loader_pdf=PyPDFLoader("Nithin Kumar KR.pdf")
docs=loader_pdf.load()
docs
# Out:
# [Document(metadata={'producer': 'Qt 4.8.7', 'creator': 'wkhtmltopdf 0.12.4', 'creationdate': '2025-02-07T03:20:57+01:00', 'title': '', 'source': 'Nithin Kumar KR.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='NITHIN KUMAR K R \nData Analyst \nData Analyst with 3+ years of experience interpreting and analyzing data in\norder to drive successful business solutions. Proﬁcient knowledge in Python\n, Mysql , Metabase, Data Science, Data Engineering, AWS, Analytics, ETL,\nAirbyte , Splunk , Pyspark \nnithinkumarkr37@gmail.com \n8317487852 \nlinkedin.com/in/nithin-kumar-k-r-69a0b0192 \nWORK EXPERIENCE \nData Analyst \nStraive - Visa \n08/2024 - Present\n, \n \nBengaluru \nLed a data Analyst team proﬁcient in Python and SQL, conducting extensive data\nmining and analysis on large datasets, yielding actionable insights and driving\ninformed decision-making through advanced analytics techniques. \nPerformed statistical analysis using Python libraries such as NumPy, Pandas
# ...

# %%
#how to recursively split text by characters
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)  # Fixed typo
texts = [doc.page_content for doc in docs]
final_docs = text_splitter.create_documents(texts)
final_docs
# Out:
# [Document(metadata={}, page_content='NITHIN KUMAR K R \nData Analyst \nData Analyst with 3+ years of experience interpreting and analyzing data in\norder to drive successful business solutions. Proﬁcient knowledge in Python\n, Mysql , Metabase, Data Science, Data Engineering, AWS, Analytics, ETL,\nAirbyte , Splunk , Pyspark \nnithinkumarkr37@gmail.com \n8317487852 \nlinkedin.com/in/nithin-kumar-k-r-69a0b0192 \nWORK EXPERIENCE \nData Analyst \nStraive - Visa \n08/2024 - Present\n, \n \nBengaluru'),
# ...

# %%
print("---------------------------------------------------------------------------------------")
for i in range(5,7):
    print(final_docs[i])
    print("---------------------------------------------------------------------------------------")
#print(final_docs[6])
# Out:
# ---------------------------------------------------------------------------------------
# page_content='alignment with project objectives and client needs, fostering eﬃcient
# communication and synergy across departments.
# Led the development of a comprehensive leadership dashboard, delivering daily
# insights on sales, revenue, spending, and various metrics to NBFC/Bank leadership
# and owners.
# Having experience in Airbyte for orchestrating extract, transform, and load (ETL)
# processes, ensuring seamless data extraction, transformation, and loading
# operations within a data pipeline framework .'
# ---------------------------------------------------------------------------------------
# page_content='operations within a data pipeline framework .
# Proﬁciently leveraged various AWS services, including ETL Glue jobs, Secret
# Manager, Crawlers, Key Management Services (KMS), S3 buckets, and Data
# Catalogs, to design and implement robust and scalable data pipelines.
# ...

# %%
##test loader
from langchain_community.document_loaders import TextLoader

loader = TextLoader('speach.txt')
text =loader.load()
text
# Out:
# [Document(metadata={'source': 'speach.txt'}, page_content="Earth is a planet in our solar system that's home to life. It's the third planet from the sun and the fifth largest planet in our solar system. \nPhysical characteristics\nShape: Earth is a sphere with a diameter of 7,917.5 miles \nComposition: Earth is made of rock, metals, and silicate rocks \nAtmosphere: Earth's atmosphere is made of 78% nitrogen, 21% oxygen, and 1% other gases \nMagnetic field: Earth's magnetic field is generated by convection currents in the outer core \nMotion \nRotation: Earth rotates on its axis every 23.9 hours, which defines day and night\nOrbit: Earth orbits the sun every 365.25 days, which defines the year\nOther facts\nEarth is known as the blue planet because of its large amount of water \nEarth's highest mountain is Mount Everest, which is part of the Himalayan mountain range \nEarth's surface is constantly changing due to convection cells inside the planet \nEarth's atmosphere protects us from
# ...

# %%
speech=''
with open("speach.txt") as f:
    speech=f.read()
    #print(speech)
#speech

text_splitter=RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=10)

text=text_splitter.create_documents([speech])

print(text[0])
# Out:
# page_content='Earth is a planet in our solar system that's home to life. It's the third planet from the sun and the fifth largest planet in our solar system.
# Physical characteristics
# Shape: Earth is a sphere with a diameter of 7,917.5 miles
# Composition: Earth is made of rock, metals, and silicate rocks
# Atmosphere: Earth's atmosphere is made of 78% nitrogen, 21% oxygen, and 1% other gases
# Magnetic field: Earth's magnetic field is generated by convection currents in the outer core
# Motion'
