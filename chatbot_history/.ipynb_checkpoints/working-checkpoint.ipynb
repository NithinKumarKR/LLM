# %%
from fastapi import FastAPI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langserve import add_routes
from langchain_groq.chat_models import ChatGroq
import uvicorn
import os
from dotenv import load_dotenv
from pydantic import BaseModel, ConfigDict
from langchain_core.messages import HumanMessage
import aiohttp
from typing import Dict
from pydantic.v1 import BaseModel, Field

# %%
model = ChatGroq(model="Gemma2-9b-It" , groq_api_key=groq_api_key)
model.invoke([HumanMessage(content="Hi , My name is Nithin")])
# Out:
# AIMessage(content="Hi Nithin, it's nice to meet you! What can I do for you today? 😊\n", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 16, 'total_tokens': 40, 'completion_time': 0.043636364, 'prompt_time': 0.002153036, 'queue_time': 0.242497603, 'total_time': 0.0457894}, 'model_name': 'Gemma2-9b-It', 'system_fingerprint': 'fp_10c08bf97d', 'finish_reason': 'stop', 'logprobs': None}, id='run-accb2ac5-25be-4ab0-858b-6fbcc3ca5b8f-0', usage_metadata={'input_tokens': 16, 'output_tokens': 24, 'total_tokens': 40})

# %%
from langchain_core.messages import AIMessage
model.invoke(
    [
        HumanMessage(content="Hi , My name is Nithin"),
        AIMessage(content="Hi , My name is Nithin I am AI Assigment") ,
        HumanMessage(content="Hi , What is my name")
    ]
)
# Out:
# AIMessage(content='Your name is Nithin.  I remember from our first conversation! 😊  Is there anything else I can help you with?\n', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 45, 'total_tokens': 74, 'completion_time': 0.052727273, 'prompt_time': 0.003408084, 'queue_time': 0.249616296, 'total_time': 0.056135357}, 'model_name': 'Gemma2-9b-It', 'system_fingerprint': 'fp_10c08bf97d', 'finish_reason': 'stop', 'logprobs': None}, id='run-38285f66-d105-4cd6-8227-4d1b21ff6485-0', usage_metadata={'input_tokens': 45, 'output_tokens': 29, 'total_tokens': 74})

# %%
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

store={}

def get_session_hist(session_id:str)->BaseChatMessageHistory:
    if session_id not in store:
        #pass
        store[session_id]=ChatMessageHistory()
    return store[session_id]

# %%
config={"configurable":{"session_id":"chat1"}}
