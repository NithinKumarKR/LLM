# %% [markdown]
# # Data Ingestion

# %%
from langchain_core.documents import Document

# %%
import bs4
from langchain_community.document_loaders import WebBaseLoader

page_url = "https://www.naukri.com/data-scientist-jobs?k=data%20scientist&nignbevent_src=jobsearchDeskGNB&experience=4&jobAge=1"

loader = WebBaseLoader(web_paths=[page_url])
docs = []
async for doc in loader.alazy_load():
    docs.append(doc)

assert len(docs) == 1
doc = docs[0]
# Out:
# Fetching pages: 100%|##########| 1/1 [00:00<00:00,  4.01it/s]

# %%
print(f"{doc.metadata}\n")
print(doc.page_content[:500].strip())
# Out:
# {'source': 'https://www.naukri.com/data-scientist-jobs?k=data%20scientist&nignbevent_src=jobsearchDeskGNB&experience=4&jobAge=1', 'language': 'en'}

# %%
from langchain_unstructured import UnstructuredLoader

page_url = "https://www.naukri.com/data-scientist-jobs?k=data%20scientist&nignbevent_src=jobsearchDeskGNB&experience=4&jobAge=1"
loader = UnstructuredLoader(web_url=page_url)

docs = []
async for doc in loader.alazy_load():
    docs.append(doc)
for doc in docs[:5]:
    print(doc.page_content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_unstructured\document_loaders.py:236, in _SingleDocumentLoader._elements_via_local(self)
#     235 try:
# --> 236     from unstructured.partition.auto import partition  # type: ignore
#     237 except ImportError:
#
# ModuleNotFoundError: No module named 'unstructured'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 7
#       4 loader = UnstructuredLoader(web_url=page_url)
#       6 docs = []
# ----> 7 async for doc in loader.alazy_load():
#       8     docs.append(doc)
#       9 for doc in docs[:5]:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\document_loaders\base.py:83, in BaseLoader.alazy_load(self)
# ...

# %%
# !pip install langchain_unstructured
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ------------------------------------- 981.5/981.5 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 12.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#    ---------------------------------------- 590.6/590.6 kB 7.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 16.2 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993251 sha256=af638f9ed46b24a18f3464c6dbea4413487c9767dfd53fc6619deac01ee0c184
# ...
