# %%
import os
from dotenv import load_dotenv
import warnings
from tqdm import TqdmWarning

warnings.filterwarnings("ignore", category=TqdmWarning)
load_dotenv()
# Out:
# True

# %%
token="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"

# %%
import os

# Set token in environment (for testing; usually, it should be set externally)
os.environ["token"] = "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"

# Get token from environment
hf_token = os.getenv("token")  
if hf_token is None:
    raise ValueError("Environment variable 'token' is not set")

# Assign to HF_TOKEN
os.environ["HF_TOKEN"] = hf_token

print("HF_TOKEN set successfully!")
# Out:
# HF_TOKEN set successfully!

# %%
import sentence_transformers
from langchain_community.embeddings import HuggingFaceEmbeddings
emb = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
text="thisis text dcoument"

# %%
query=emb.embed_query(text)
len(query)
# Out:
# 384
