# %% [markdown]
# ### Embedding Technique
# converting text into vectors

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY="sk----"

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
emb=OpenAIEmbeddings(model="text_embedding-3-large")
emb
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x00000210C4B69C00>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x00000210C4DAA500>, model='text_embedding-3-large', dimensions=None, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr(''), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
text="This is done"
query_result = emb.embed_query(text)
query_result
# Out:
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File d:\nithin\Lagchain\venv\lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File d:\nithin\Lagchain\venv\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File d:\nithin\Lagchain\venv\lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# ...

# %%
len(query_result)

# %%
from langchain_openai import OpenAIEmbeddings
emb=OpenAIEmbeddings(model="text_embedding-3-large",dimensions=1024)
emb
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x00000210C8392E00>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x00000210C8391570>, model='text_embedding-3-large', dimensions=1024, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr(''), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
text="This is done"
query_result = emb.embed_query(text)
query_result
# Out:
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File d:\nithin\Lagchain\venv\lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File d:\nithin\Lagchain\venv\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File d:\nithin\Lagchain\venv\lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# ...

# %%
## Text Splitting From Documents
##reading a PDF file
from langchain_community.document_loaders import PyPDFLoader
loader_pdf=PyPDFLoader("Data_injection/Nithin Kumar KR.pdf")
docs=loader_pdf.load()
docs
# Out:
# [Document(metadata={'producer': 'Qt 4.8.7', 'creator': 'wkhtmltopdf 0.12.4', 'creationdate': '2025-02-07T03:20:57+01:00', 'title': '', 'source': 'Data_injection/Nithin Kumar KR.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='NITHIN KUMAR K R \nData Analyst \nData Analyst with 3+ years of experience interpreting and analyzing data in\norder to drive successful business solutions. Proﬁcient knowledge in Python\n, Mysql , Metabase, Data Science, Data Engineering, AWS, Analytics, ETL,\nAirbyte , Splunk , Pyspark \nnithinkumarkr37@gmail.com \n8317487852 \nlinkedin.com/in/nithin-kumar-k-r-69a0b0192 \nWORK EXPERIENCE \nData Analyst \nStraive - Visa \n08/2024 - Present\n, \n \nBengaluru \nLed a data Analyst team proﬁcient in Python and SQL, conducting extensive data\nmining and analysis on large datasets, yielding actionable insights and driving\ninformed decision-making through advanced analytics techniques. \nPerformed statistical analysis using Python libraries such a
# ...

# %%
#how to recursively split text by characters
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)  # Fixed typo
texts = [doc.page_content for doc in docs]
final_docs = text_splitter.create_documents(texts)
final_docs
# Out:
# [Document(metadata={}, page_content='NITHIN KUMAR K R \nData Analyst \nData Analyst with 3+ years of experience interpreting and analyzing data in\norder to drive successful business solutions. Proﬁcient knowledge in Python\n, Mysql , Metabase, Data Science, Data Engineering, AWS, Analytics, ETL,\nAirbyte , Splunk , Pyspark \nnithinkumarkr37@gmail.com \n8317487852 \nlinkedin.com/in/nithin-kumar-k-r-69a0b0192 \nWORK EXPERIENCE \nData Analyst \nStraive - Visa \n08/2024 - Present\n, \n \nBengaluru'),
# ...

# %%
from langchain_community.vectorstores import Chroma

db = Chroma.from_documents(final_docs ,emb)
# Out:
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File d:\nithin\Lagchain\venv\lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File d:\nithin\Lagchain\venv\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File d:\nithin\Lagchain\venv\lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# ...

# %%
query="ITs done"
retri = db.similarity_search(query)
print(retri)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 query="ITs done"
# ----> 2 retri = db.similarity_search(query)
#       3 print(retri)
#
# NameError: name 'db' is not defined
